# %%
# %matplotlib inline

# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
from sklearn.linear_model import Ridge
warnings.filterwarnings('ignore')

# %%
FB_file = "Each_SM_data_set/FB_data.csv"
FB_df = pd.read_csv(FB_file)
Twitter_file = "Each_SM_data_set/Twitter_data.csv"
Twitter_df = pd.read_csv(Twitter_file)
Insta_file = "Each_SM_data_set/Instagram_data.csv"
Insta_df = pd.read_csv(Insta_file)
Youtube_file = "Each_SM_data_set/Youtube_data.csv"
Youtube_df = pd.read_csv(Youtube_file)
Reddit_file = "Each_SM_data_set/Reddit_data.csv"
Reddit_df = pd.read_csv(Reddit_file)
Disc_file = "Each_SM_data_set/Discord_data.csv"
Disc_df = pd.read_csv(Disc_file)
Pin_file = "Each_SM_data_set/Pintrest_data.csv"
Pin_df = pd.read_csv(Pin_file)
Tiktok_file = "Each_SM_data_set/Tiktok_data.csv"
Tiktok_df = pd.read_csv(Tiktok_file)

# %%
FB_avg = FB_df["How often do you feel depressed or down?"].mean()
Twitter_avg = Twitter_df["How often do you feel depressed or down?"].mean()
Youtube_avg = Youtube_df["How often do you feel depressed or down?"].mean()
Reddit_avg = Reddit_df["How often do you feel depressed or down?"].mean()
Insta_avg = Insta_df["How often do you feel depressed or down?"].mean()
Tiktok_avg = Tiktok_df["How often do you feel depressed or down?"].mean()
print(Twitter_avg,FB_avg,Insta_avg,Youtube_avg,Reddit_avg,Tiktok_avg)
# Out:
# 3.25 3.321243523316062 3.391812865497076 3.2764857881136953 3.3076923076923075 3.6818181818181817

# %%
FB_time = FB_df.groupby(["Average time on social media (per Day)"])["How often do you feel depressed or down?"].mean()
Twitter_time = Twitter_df.groupby(["Average time on social media (per Day)"])["How often do you feel depressed or down?"].mean()
Insta_time = Insta_df.groupby(["Average time on social media (per Day)"])["How often do you feel depressed or down?"].mean()
Youtube_time = Youtube_df.groupby(["Average time on social media (per Day)"])["How often do you feel depressed or down?"].mean()
Reddit_time = Reddit_df.groupby(["Average time on social media (per Day)"])["How often do you feel depressed or down?"].mean()
Disc_time = Disc_df.groupby(["Average time on social media (per Day)"])["How often do you feel depressed or down?"].mean()
Pin_time = Pin_df.groupby(["Average time on social media (per Day)"])["How often do you feel depressed or down?"].mean()
Tiktok_time = Tiktok_df.groupby(["Average time on social media (per Day)"])["How often do you feel depressed or down?"].mean()
print(Twitter_time, FB_time, Insta_time, Youtube_time, Reddit_time,Tiktok_time)
# Out:
# Average time on social media (per Day)
# Between 1 and 2 hours    3.117647
# Between 2 and 3 hours    2.896552
# Between 3 and 4 hours    3.095238
# Between 4 and 5 hours    3.894737
# Less than an Hour        2.400000
# More than 5 hours        3.625000
# Name: How often do you feel depressed or down?, dtype: float64 Average time on social media (per Day)
# Between 1 and 2 hours    2.880000
# Between 2 and 3 hours    3.246753
# Between 3 and 4 hours    3.386667
# Between 4 and 5 hours    3.464286
# Less than an Hour        2.000000
# More than 5 hours        3.858586
# Name: How often do you feel depressed or down?, dtype: float64 Average time on social media (per Day)
# Between 1 and 2 hours    3.025641
# Between 2 and 3 hours    3.295775
# Between 3 and 4 hours    3.442857
# Between 4 and 5 hours    3.425926
# Less than an Hour        2.133333
# More than 5 hours        3.763441
# ...

# %%
FB_time = FB_time.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])
Twitter_time = Twitter_time.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])
Insta_time = Insta_time.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])
Youtube_time = Youtube_time.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])
Reddit_time = Reddit_time.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])
Disc_time = Disc_time.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])
Pin_time = Pin_time.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])
Tiktok_time = Tiktok_time.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])

# %%
FB = FB_time.plot(kind='bar', title='Time spent of Facebook vs. Average of how depressed individuals are',
               ylabel='How often do you feel depressed or down?', xlabel='Average time on social media (per Day)', figsize=(8, 6), color = ((66/255),(103/255),(178/255)))
plt.tight_
plt.savefig("Data_Images/FB_TimevsDep")

# %%
Twitter = Twitter_time.plot(kind='bar', title='Time spent of Twitter vs. Average of how depressed individuals are',
               ylabel='How often do you feel depressed or down?', xlabel='Average time on social media (per Day)', figsize=(8, 6), color = ((29/255),(161/255),(242/255)))
plt.tight_layout()
plt.savefig("Data_Images/Twitter_TimevsDep")

# %%
Insta = Insta_time.plot(kind='bar', title='Time spent of Instagram vs. Average of how depressed individuals are',
               ylabel='How often do you feel depressed or down?', xlabel='Average time on social media (per Day)', figsize=(8, 6), color = ((193/255),(53/255),(132/255)))
plt.tight_layout()
plt.savefig("Data_Images/Insta_TimevsDep")

# %%
Youtube = Youtube_time.plot(kind='bar', title='Time spent of Youtube vs. Average of how depressed individuals are',
               ylabel='How often do you feel depressed or down?', xlabel='Average time on social media (per Day)', figsize=(8, 6), color = (1,0,0))
plt.tight_layout()
plt.savefig("Data_Images/Youtube_TimevsDep")

# %%
Reddit = Reddit_time.plot(kind='bar', title='Time spent of Reddit vs. Average of how depressed individuals are',
               ylabel='How often do you feel depressed or down?', xlabel='Average time on social media (per Day)', figsize=(8, 6), color = (1,(69/255),0))
plt.tight_layout()
plt.savefig("Data_Images/Reddit_TimevsDep")

# %%
Disc = Disc_time.plot(kind='bar', title='Time spent of Discord vs. Average of how depressed individuals are',
               ylabel='How often do you feel depressed or down?', xlabel='Average time on social media (per Day)', figsize=(8, 6), color = ((88/255),(101/255),(242/255)))
plt.tight_layout()
plt.savefig("Data_Images/Disc_TimevsDep")

# %%
Pinterest = Pin_time.plot(kind='bar', title='Time spent of Pinterst vs. Average of how depressed individuals are',
               ylabel='How often do you feel depressed or down?', xlabel='Average time on social media (per Day)', figsize=(8, 6), color = ((230/255),0,(35/255)))
plt.tight_layout()
plt.savefig("Data_Images/Pinterest_TimevsDep")

# %%
Tiktok = Tiktok_time.plot(kind='bar', title='Time spent of Tiktok vs. Average of how depressed individuals are',
               ylabel='How often do you feel depressed or down?', xlabel='Average time on social media (per Day)', figsize=(8, 6), color = (0,(242/255),(234/255)))
plt.tight_layout()
plt.savefig("Data_Images/Tiktok_TimevsDep")

# %%
FB_two = FB_df.groupby(["Average time on social media (per Day)"])["On a scale of 1 to 5, how much are you bothered by worries?"].mean()
Twitter_two = Twitter_df.groupby(["Average time on social media (per Day)"])["On a scale of 1 to 5, how much are you bothered by worries?"].mean()
Insta_two = Insta_df.groupby(["Average time on social media (per Day)"])["On a scale of 1 to 5, how much are you bothered by worries?"].mean()
Youtube_two = Youtube_df.groupby(["Average time on social media (per Day)"])["On a scale of 1 to 5, how much are you bothered by worries?"].mean()
Reddit_two = Reddit_df.groupby(["Average time on social media (per Day)"])["On a scale of 1 to 5, how much are you bothered by worries?"].mean()
Disc_two = Disc_df.groupby(["Average time on social media (per Day)"])["On a scale of 1 to 5, how much are you bothered by worries?"].mean()
Pin_two = Pin_df.groupby(["Average time on social media (per Day)"])["On a scale of 1 to 5, how much are you bothered by worries?"].mean()
Tiktok_two = Tiktok_df.groupby(["Average time on social media (per Day)"])["On a scale of 1 to 5, how much are you bothered by worries?"].mean()
print(Twitter_two, FB_two, Insta_two, Youtube_two, Reddit_two,Tiktok_two)
# Out:
# Average time on social media (per Day)
# Between 1 and 2 hours    3.352941
# Between 2 and 3 hours    3.379310
# Between 3 and 4 hours    3.952381
# Between 4 and 5 hours    3.894737
# Less than an Hour        2.800000
# More than 5 hours        4.000000
# Name: On a scale of 1 to 5, how much are you bothered by worries?, dtype: float64 Average time on social media (per Day)
# Between 1 and 2 hours    3.160000
# Between 2 and 3 hours    3.363636
# Between 3 and 4 hours    3.920000
# Between 4 and 5 hours    3.732143
# Less than an Hour        2.413793
# More than 5 hours        4.101010
# Name: On a scale of 1 to 5, how much are you bothered by worries?, dtype: float64 Average time on social media (per Day)
# Between 1 and 2 hours    3.282051
# Between 2 and 3 hours    3.577465
# Between 3 and 4 hours    4.014286
# Between 4 and 5 hours    3.722222
# Less than an Hour        2.733333
# More than 5 hours        4.021505
# ...

# %%
FB_two = FB_two.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])
Twitter_two = Twitter_two.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])
Insta_two = Insta_two.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])
Youtube_two = Youtube_two.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])
Reddit_two = Reddit_two.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])
Disc_two = Disc_two.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])
Pin_two = Pin_two.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])
Tiktok_two = Tiktok_two.reindex(["Less than an Hour","Between 1 and 2 hours","Between 2 and 3 hours","Between 3 and 4 hours","Between 4 and 5 hours","More than 5 hours"])

# %%
FBanx = FB_two.plot(kind='bar', title='Time spent of Facebook vs. Average of how stressed individuals are',
               ylabel='How much are you bothered by worries? (Anixety)', xlabel='Average time on social media (per Day)', figsize=(8, 6), color = ((66/255),(103/255),(178/255)))
plt.tight_layout()
plt.savefig("Data_Images/FB_TimevsAnx")

# %%
Twitteranx = Twitter_two.plot(kind='bar', title='Time spent of Twitter vs. Average of how stressed individuals are',
               ylabel='How much are you bothered by worries? (Anixety)', xlabel='Average time on social media (per Day)', figsize=(8, 6), color = ((29/255),(161/255),(242/255)))
plt.tight_layout()
plt.savefig("Data_Images/Twitter_TimevsAnx")

# %%
Instaanx = Insta_two.plot(kind='bar', title='Time spent of Instagram vs. Average of how stressed individuals are',
               ylabel='How much are you bothered by worries? (Anixety)', xlabel='Average time on social media (per Day)', figsize=(8, 6), color = ((193/255),(53/255),(132/255)))
plt.tight_layout()
plt.savefig("Data_Images/Insta_TimevsAnx")

# %%
Youtubeanx = Youtube_two.plot(kind='bar', title='Time spent of Youtube vs. Average of how stressed individuals are',
               ylabel='How much are you bothered by worries? (Anixety)', xlabel='Average time on social media (per Day)', figsize=(8, 6), color = (1,0,0))
plt.tight_layout()
plt.savefig("Data_Images/Youtube_TimevsAnx")

# %%
Redditanx = Reddit_two.plot(kind='bar', title='Time spent of Reddit vs. Average of how stressed individuals are',
               ylabel='How much are you bothered by worries? (Anixety)', xlabel='Average time on social media (per Day)', figsize=(8, 6), color = (1,(69/255),0))
plt.tight_layout()
plt.savefig("Data_Images/Reddit_TimevsAnx")

# %%
Tiktokanx = Tiktok_two.plot(kind='bar', title='Time spent of Tiktok vs. Average of how stressed individuals are',
               ylabel='How much are you bothered by worries? (Anixety)', xlabel='Average time on social media (per Day)', figsize=(8, 6), color = (0,(242/255),(234/255)))
plt.tight_layout()
plt.savefig("Data_Images/Tiktok_TimevsAnx")

# %%
FB_avg2 = FB_df["On a scale of 1 to 5, how much are you bothered by worries?"].mean()
Twitter_avg2 = Twitter_df["On a scale of 1 to 5, how much are you bothered by worries?"].mean()
Youtube_avg2 = Youtube_df["On a scale of 1 to 5, how much are you bothered by worries?"].mean()
Reddit_avg2 = Reddit_df["On a scale of 1 to 5, how much are you bothered by worries?"].mean()
Insta_avg2 = Insta_df["On a scale of 1 to 5, how much are you bothered by worries?"].mean()
Tiktok_avg2 = Tiktok_df["On a scale of 1 to 5, how much are you bothered by worries?"].mean()
print(Twitter_avg2,FB_avg2,Insta_avg2,Youtube_avg2,Reddit_avg2,Tiktok_avg2)
# Out:
# 3.65625 3.616580310880829 3.739766081871345 3.607235142118863 3.7435897435897436 3.9886363636363638
