# %%
import pandas as pd

# %%
data_file = "smmh.csv"
data_file_df = pd.read_csv(data_file)
data_file_df.head()
# Out:
#             Timestamp  ...  20. On a scale of 1 to 5, how often do you face issues regarding sleep?
# 0  4/18/2022 19:18:47  ...                                                  5
# 1  4/18/2022 19:19:28  ...                                                  5
# 2  4/18/2022 19:25:59  ...                                                  5
# 3  4/18/2022 19:29:43  ...                                                  2
# 4  4/18/2022 19:33:31  ...                                                  1
#
# [5 rows x 21 columns]

# %%
#dropping nan data
data_pd = data_file_df.dropna()
data_pd = data_pd.drop(columns = "Timestamp")
data_pd.head()
# Out:
#    1. What is your age?  ... 20. On a scale of 1 to 5, how often do you face issues regarding sleep?
# 0                  21.0  ...                                                  5
# 1                  21.0  ...                                                  5
# 2                  21.0  ...                                                  5
# 3                  21.0  ...                                                  2
# 4                  21.0  ...                                                  1
#
# [5 rows x 20 columns]

# %%
data_pd = data_pd.rename(columns={"1. What is your age?": "Age", "2. Gender": "Gender", "3. Relationship Status" : "Relationship", "4. Occupation Status": "Occupation", "5. What type of organizations are you affiliated with?": "Affiliation", "6. Do you use social media?": "Use Social Media (Y/N)", "7. What social media platforms do you commonly use?": "Soical Media Platforms Used", "8. What is the average time you spend on social media every day?": "Average time on social media (per Day)"})
data_pd = data_pd.rename(columns= {"9. How often do you find yourself using Social media without a specific purpose?": "How often do you find yourself using Social media without a specific purpose?", "10. How often do you get distracted by Social media when you are busy doing something?": "How often do you get distracted by Social media when you are busy doing something?", "11. Do you feel restless if you haven't used Social media in a while?" : "Do you feel restless if you haven't used Social media in a while?", "12. On a scale of 1 to 5, how easily distracted are you?":"On a scale of 1 to 5, how easily distracted are you?", "13. On a scale of 1 to 5, how much are you bothered by worries?": "On a scale of 1 to 5, how much are you bothered by worries?", "14. Do you find it difficult to concentrate on things?": "Do you find it difficult to concentrate on things?", "15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?" : "On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?", "16. Following the previous question, how do you feel about these comparisons, generally speaking?": "Following the previous question, how do you feel about these comparisons, generally speaking?", "17. How often do you look to seek validation from features of social media?":"How often do you look to seek validation from features of social media?", "18. How often do you feel depressed or down?":"How often do you feel depressed or down?", "19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?": "On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?", "20. On a scale of 1 to 5, how often do you face issues regarding sleep?": "On a scale of 1 to 5, how often do you face issues regarding sleep?"})
data_pd.head()
data_pd = data_pd.drop(columns = ["Relationship", "Affiliation"])
data_pd = data_pd.reset_index()
data_pd
# Out:
#      index  ...  On a scale of 1 to 5, how often do you face issues regarding sleep?
# 0        0  ...                                                  5
# 1        1  ...                                                  5
# 2        2  ...                                                  5
# 3        3  ...                                                  2
# 4        4  ...                                                  1
# ..     ...  ...                                                ...
# 446    476  ...                                                  4
# 447    477  ...                                                  1
# 448    478  ...                                                  2
# 449    479  ...                                                  4
# 450    480  ...                                                  3
#
# [451 rows x 19 columns]

# %%
data_pd.to_csv("clean_data.csv", index = False, header=True)
# Out:
# Traceback (most recent call last):
#
#   Cell In[9], line 1
#     data_pd.to_csv("clean_data.csv", index = False, header=True)
#
#   File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211 in wrapper
#     return func(*args, **kwargs)
#
#   File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3720 in to_csv
#     return DataFrameRenderer(formatter).to_csv(
#
#   File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211 in wrapper
#     return func(*args, **kwargs)
#
#   File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1189 in to_csv
#     csv_formatter.save()
#
#   File ~\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:241 in save
#     with get_handle(
#
#   File ~\anaconda3\Lib\site-packages\pandas\io\common.py:856 in get_handle
#     handle = open(
#
# PermissionError: [Errno 13] Permission denied: 'clean_data.csv'

# %%
list(data_pd.columns)
# Out:
# ['index',
#  'Age',
#  'Gender',
#  'Occupation',
#  'Use Social Media (Y/N)',
#  'Soical Media Platforms Used',
#  'Average time on social media (per Day)',
#  'How often do you find yourself using Social media without a specific purpose?',
#  'How often do you get distracted by Social media when you are busy doing something?',
#  "Do you feel restless if you haven't used Social media in a while?",
#  'On a scale of 1 to 5, how easily distracted are you?',
#  'On a scale of 1 to 5, how much are you bothered by worries?',
#  'Do you find it difficult to concentrate on things?',
#  'On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?',
#  'Following the previous question, how do you feel about these comparisons, generally speaking?',
#  'How often do you look to seek validation from features of social media?',
#  'How often do you feel depressed or down?',
# ...

# %%
FB_df = pd.DataFrame()
Twitter_df = pd.DataFrame()
Insta_df = pd.DataFrame()
Youtube_df = pd.DataFrame()
Reddit_df = pd.DataFrame()
Disc_df = pd.DataFrame()
Pin_df = pd.DataFrame()
Tiktok_df = pd.DataFrame()

# %%
for i, row in data_pd.iterrows():
    x = str(data_pd["Soical Media Platforms Used"][i])
    sep = (x.split(", "))
    for j in (range(len(sep))):
        if (sep[j] == "Facebook") & (i <451):
            FB_temp = pd.DataFrame({
                 "Age": [data_pd.iloc[i,1]],
                 'Gender': data_pd.iloc[i,2],
                 'Occupation': data_pd.iloc[i,3],
                 'Use Social Media (Y/N)': data_pd.iloc[i,4], 
                 'Soical Media Platforms Used': data_pd.iloc[i,5], 
                 'Average time on social media (per Day)': data_pd.iloc[i,6],
                 'How often do you find yourself using Social media without a specific purpose?':data_pd.iloc[i,7],
                 'How often do you get distracted by Social media when you are busy doing something?': data_pd.iloc[i,8],
                 "Do you feel restless if you haven't used Social media in a while?": data_pd.iloc[i,9],
                 'On a scale of 1 to 5, how easily distracted are you?': data_pd.iloc[i,10],
                 'On a scale of 1 to 5, how much are you bothered by worries?':data_pd.iloc[i,11],
                 'Do you find it difficult to concentrate on things?': data_pd.iloc[i,12],
                 'On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?': data_pd.iloc[i,13],
                 'Following the previous question, how do you feel about these comparisons, generally speaking?': data_pd.iloc[i,14],
                 'How often do you look to seek validation from features of social media?':data_pd.iloc[i,15],
                 'How often do you feel depressed or down?':data_pd.iloc[i,16],
                 'On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?': data_pd.iloc[i,17],
                 'On a scale of 1 to 5, how often do you face issues regarding sleep?': data_pd.iloc[i,18]
            })
            FB_df = FB_df.append(FB_temp)
        if (sep[j] == 'Twitter') & (i<451):
            Twitter_temp = pd.DataFrame({
                 "Age": [data_pd.iloc[i,1]],
                 'Gender': data_pd.iloc[i,2],
                 'Occupation': data_pd.iloc[i,3],
                 'Use Social Media (Y/N)': data_pd.iloc[i,4], 
                 'Soical Media Platforms Used': data_pd.iloc[i,5], 
                 'Average time on social media (per Day)': data_pd.iloc[i,6],
                 'How often do you find yourself using Social media without a specific purpose?':data_pd.iloc[i,7],
                 'How often do you get distracted by Social media when you are busy doing something?': data_pd.iloc[i,8],
                 "Do you feel restless if you haven't used Social media in a while?": data_pd.iloc[i,9],
                 'On a scale of 1 to 5, how easily distracted are you?': data_pd.iloc[i,10],
                 'On a scale of 1 to 5, how much are you bothered by worries?':data_pd.iloc[i,11],
                 'Do you find it difficult to concentrate on things?': data_pd.iloc[i,12],
                 'On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?': data_pd.iloc[i,13],
                 'Following the previous question, how do you feel about these comparisons, generally speaking?': data_pd.iloc[i,14],
                 'How often do you look to seek validation from features of social media?':data_pd.iloc[i,15],
                 'How often do you feel depressed or down?':data_pd.iloc[i,16],
                 'On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?': data_pd.iloc[i,17],
                 'On a scale of 1 to 5, how often do you face issues regarding sleep?': data_pd.iloc[i,18]
            })
            Twitter_df = Twitter_df.append(Twitter_temp)
        if (sep[j] == 'Instagram') & (i<451):
            Insta_temp = pd.DataFrame({
                 "Age": [data_pd.iloc[i,1]],
                 'Gender': data_pd.iloc[i,2],
                 'Occupation': data_pd.iloc[i,3],
                 'Use Social Media (Y/N)': data_pd.iloc[i,4], 
                 'Soical Media Platforms Used': data_pd.iloc[i,5], 
                 'Average time on social media (per Day)': data_pd.iloc[i,6],
                 'How often do you find yourself using Social media without a specific purpose?':data_pd.iloc[i,7],
                 'How often do you get distracted by Social media when you are busy doing something?': data_pd.iloc[i,8],
                 "Do you feel restless if you haven't used Social media in a while?": data_pd.iloc[i,9],
                 'On a scale of 1 to 5, how easily distracted are you?': data_pd.iloc[i,10],
                 'On a scale of 1 to 5, how much are you bothered by worries?':data_pd.iloc[i,11],
                 'Do you find it difficult to concentrate on things?': data_pd.iloc[i,12],
                 'On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?': data_pd.iloc[i,13],
                 'Following the previous question, how do you feel about these comparisons, generally speaking?': data_pd.iloc[i,14],
                 'How often do you look to seek validation from features of social media?':data_pd.iloc[i,15],
                 'How often do you feel depressed or down?':data_pd.iloc[i,16],
                 'On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?': data_pd.iloc[i,17],
                 'On a scale of 1 to 5, how often do you face issues regarding sleep?': data_pd.iloc[i,18]
            })
            Insta_df = Insta_df.append(Insta_temp)
        if (sep[j] == 'Youtube') & (i<451):
            Youtube_temp = pd.DataFrame({
                 "Age": [data_pd.iloc[i,1]],
                 'Gender': data_pd.iloc[i,2],
                 'Occupation': data_pd.iloc[i,3],
                 'Use Social Media (Y/N)': data_pd.iloc[i,4], 
                 'Soical Media Platforms Used': data_pd.iloc[i,5], 
                 'Average time on social media (per Day)': data_pd.iloc[i,6],
                 'How often do you find yourself using Social media without a specific purpose?':data_pd.iloc[i,7],
                 'How often do you get distracted by Social media when you are busy doing something?': data_pd.iloc[i,8],
                 "Do you feel restless if you haven't used Social media in a while?": data_pd.iloc[i,9],
                 'On a scale of 1 to 5, how easily distracted are you?': data_pd.iloc[i,10],
                 'On a scale of 1 to 5, how much are you bothered by worries?':data_pd.iloc[i,11],
                 'Do you find it difficult to concentrate on things?': data_pd.iloc[i,12],
                 'On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?': data_pd.iloc[i,13],
                 'Following the previous question, how do you feel about these comparisons, generally speaking?': data_pd.iloc[i,14],
                 'How often do you look to seek validation from features of social media?':data_pd.iloc[i,15],
                 'How often do you feel depressed or down?':data_pd.iloc[i,16],
                 'On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?': data_pd.iloc[i,17],
                 'On a scale of 1 to 5, how often do you face issues regarding sleep?': data_pd.iloc[i,18]
            })
            Youtube_df = Youtube_df.append(Youtube_temp)
        if (sep[j] == 'Reddit') & (i<451):
            Reddit_temp = pd.DataFrame({
                 "Age": [data_pd.iloc[i,1]],
                 'Gender': data_pd.iloc[i,2],
                 'Occupation': data_pd.iloc[i,3],
                 'Use Social Media (Y/N)': data_pd.iloc[i,4], 
                 'Soical Media Platforms Used': data_pd.iloc[i,5], 
                 'Average time on social media (per Day)': data_pd.iloc[i,6],
                 'How often do you find yourself using Social media without a specific purpose?':data_pd.iloc[i,7],
                 'How often do you get distracted by Social media when you are busy doing something?': data_pd.iloc[i,8],
                 "Do you feel restless if you haven't used Social media in a while?": data_pd.iloc[i,9],
                 'On a scale of 1 to 5, how easily distracted are you?': data_pd.iloc[i,10],
                 'On a scale of 1 to 5, how much are you bothered by worries?':data_pd.iloc[i,11],
                 'Do you find it difficult to concentrate on things?': data_pd.iloc[i,12],
                 'On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?': data_pd.iloc[i,13],
                 'Following the previous question, how do you feel about these comparisons, generally speaking?': data_pd.iloc[i,14],
                 'How often do you look to seek validation from features of social media?':data_pd.iloc[i,15],
                 'How often do you feel depressed or down?':data_pd.iloc[i,16],
                 'On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?': data_pd.iloc[i,17],
                 'On a scale of 1 to 5, how often do you face issues regarding sleep?': data_pd.iloc[i,18]
            })
            Reddit_df = Reddit_df.append(Reddit_temp)
        if (str(sep[j]) == 'Discord') & (i<451):
            Disc_temp = pd.DataFrame({
                 "Age": [data_pd.iloc[i,1]],
                 'Gender': data_pd.iloc[i,2],
                 'Occupation': data_pd.iloc[i,3],
                 'Use Social Media (Y/N)': data_pd.iloc[i,4], 
                 'Soical Media Platforms Used': data_pd.iloc[i,5], 
                 'Average time on social media (per Day)': data_pd.iloc[i,6],
                 'How often do you find yourself using Social media without a specific purpose?':data_pd.iloc[i,7],
                 'How often do you get distracted by Social media when you are busy doing something?': data_pd.iloc[i,8],
                 "Do you feel restless if you haven't used Social media in a while?": data_pd.iloc[i,9],
                 'On a scale of 1 to 5, how easily distracted are you?': data_pd.iloc[i,10],
                 'On a scale of 1 to 5, how much are you bothered by worries?':data_pd.iloc[i,11],
                 'Do you find it difficult to concentrate on things?': data_pd.iloc[i,12],
                 'On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?': data_pd.iloc[i,13],
                 'Following the previous question, how do you feel about these comparisons, generally speaking?': data_pd.iloc[i,14],
                 'How often do you look to seek validation from features of social media?':data_pd.iloc[i,15],
                 'How often do you feel depressed or down?':data_pd.iloc[i,16],
                 'On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?': data_pd.iloc[i,17],
                 'On a scale of 1 to 5, how often do you face issues regarding sleep?': data_pd.iloc[i,18]
            })
            Disc_df = Disc_df.append(Disc_temp)
        if (sep[j] == 'Pintrest') & (i<451):
            Pin_temp = pd.DataFrame({
                 "Age": [data_pd.iloc[i,1]],
                 'Gender': data_pd.iloc[i,2],
                 'Occupation': data_pd.iloc[i,3],
                 'Use Social Media (Y/N)': data_pd.iloc[i,4], 
                 'Soical Media Platforms Used': data_pd.iloc[i,5], 
                 'Average time on social media (per Day)': data_pd.iloc[i,6],
                 'How often do you find yourself using Social media without a specific purpose?':data_pd.iloc[i,7],
                 'How often do you get distracted by Social media when you are busy doing something?': data_pd.iloc[i,8],
                 "Do you feel restless if you haven't used Social media in a while?": data_pd.iloc[i,9],
                 'On a scale of 1 to 5, how easily distracted are you?': data_pd.iloc[i,10],
                 'On a scale of 1 to 5, how much are you bothered by worries?':data_pd.iloc[i,11],
                 'Do you find it difficult to concentrate on things?': data_pd.iloc[i,12],
                 'On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?': data_pd.iloc[i,13],
                 'Following the previous question, how do you feel about these comparisons, generally speaking?': data_pd.iloc[i,14],
                 'How often do you look to seek validation from features of social media?':data_pd.iloc[i,15],
                 'How often do you feel depressed or down?':data_pd.iloc[i,16],
                 'On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?': data_pd.iloc[i,17],
                 'On a scale of 1 to 5, how often do you face issues regarding sleep?': data_pd.iloc[i,18]
            })
            Pin_df = Pin_df.append(Pin_temp)
        if (sep[j] == 'TikTok') & (i<451):
            Tiktok_temp = pd.DataFrame({
                 "Age": [data_pd.iloc[i,1]],
                 'Gender': data_pd.iloc[i,2],
                 'Occupation': data_pd.iloc[i,3],
                 'Use Social Media (Y/N)': data_pd.iloc[i,4], 
                 'Soical Media Platforms Used': data_pd.iloc[i,5], 
                 'Average time on social media (per Day)': data_pd.iloc[i,6],
                 'How often do you find yourself using Social media without a specific purpose?':data_pd.iloc[i,7],
                 'How often do you get distracted by Social media when you are busy doing something?': data_pd.iloc[i,8],
                 "Do you feel restless if you haven't used Social media in a while?": data_pd.iloc[i,9],
                 'On a scale of 1 to 5, how easily distracted are you?': data_pd.iloc[i,10],
                 'On a scale of 1 to 5, how much are you bothered by worries?':data_pd.iloc[i,11],
                 'Do you find it difficult to concentrate on things?': data_pd.iloc[i,12],
                 'On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?': data_pd.iloc[i,13],
                 'Following the previous question, how do you feel about these comparisons, generally speaking?': data_pd.iloc[i,14],
                 'How often do you look to seek validation from features of social media?':data_pd.iloc[i,15],
                 'How often do you feel depressed or down?':data_pd.iloc[i,16],
                 'On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?': data_pd.iloc[i,17],
                 'On a scale of 1 to 5, how often do you face issues regarding sleep?': data_pd.iloc[i,18]
            })
            Tiktok_df = Tiktok_df.append(Tiktok_temp)
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_17380\919216294.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   FB_df = FB_df.append(FB_temp)
# C:\Users\matth\AppData\Local\Temp\ipykernel_17380\919216294.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Twitter_df = Twitter_df.append(Twitter_temp)
# C:\Users\matth\AppData\Local\Temp\ipykernel_17380\919216294.py:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Insta_df = Insta_df.append(Insta_temp)
# C:\Users\matth\AppData\Local\Temp\ipykernel_17380\919216294.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Disc_df = Disc_df.append(Disc_temp)
# ...

# %%
Tiktok_df
# Out:
#     Age  ...  On a scale of 1 to 5, how often do you face issues regarding sleep?
# 0     5  ...                                                  2
# 0     6  ...                                                  5
# 0    11  ...                                                  4
# 0    21  ...                                                  3
# 0    28  ...                                                  4
# ..  ...  ...                                                ...
# 0   437  ...                                                  1
# 0   439  ...                                                  3
# 0   446  ...                                                  4
# 0   452  ...                                                  4
# 0   470  ...                                                  4
#
# [88 rows x 18 columns]

# %%
FB_df.to_csv("Each_SM_data_set/FB_data.csv", index = False, header=True)
Twitter_df.to_csv("Each_SM_data_set/Twitter_data.csv", index = False, header=True)
Insta_df.to_csv("Each_SM_data_set/Instagram_data.csv", index = False, header=True)
Youtube_df.to_csv("Each_SM_data_set/Youtube_data.csv", index = False, header=True)
Reddit_df.to_csv("Each_SM_data_set/Reddit_data.csv", index = False, header=True)
Disc_df.to_csv("Each_SM_data_set/Discord_data.csv", index = False, header=True)
Pin_df.to_csv("Each_SM_data_set/Pintrest_data.csv", index = False, header=True)
Tiktok_df.to_csv("Each_SM_data_set/Tiktok_data.csv", index = False, header=True)
